# %%
import pickle
import pandas as pd

# %%
# !ls ../data/pickles
# Out:
# df_full.pickle

# %%
df = pickle.load(open('../data/pickles/df_full.pickle', 'rb'))

# %%
df.to_csv('../data/full_df.csv')

# %%
df
# Out:
#        recid_flag  target_pop_flag  year_released_2010  year_released_2011  \
# 49              1                1                   1                   0
# 50              1                0                   1                   0
# 51              1                1                   1                   0
# 52              0                1                   1                   0
# 53              1                0                   1                   0
# 54              0                1                   1                   0
# 55              0                1                   1                   0
# 56              1                1                   1                   0
# 57              0                1                   1                   0
# 58              1                1                   1                   0
# 59              1                1                   1                   0
# ...
