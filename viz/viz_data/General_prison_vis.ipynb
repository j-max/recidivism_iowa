# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
years = [2000,2010,2015,2016]
prison_pop = [1938500,1517800,2166600,2157800]
years_parole = [2007, 2016]
parole_pop = [826100, 874800]

# %%
fig, ax = plt.subplots()
plt.plot(years, prison_pop)
ax.set_ylim(bottom=0)

plt.plot(years_parole, parole_pop)

# %%
# year1=[,,,3839400,725500]
# ,,,4236800,798200
# ,,,4293000,826100
# ,,,4271200,826100
# ,,,4199800,824600
# ,,,4055900,840800
# ,,,3973800,855500
# ,,,3944900,858400
# ,,,3912900,849500
# ,,,3868400,857700
# ,,,3789800,870500

years = [2000,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
total = [6467800,7199600,7339600,7312600,7239100,7089000,6994500,6949800,6899700,6856900,6740300]
total_commsup = [4564900,5035000,5119000,5093400,5019900,4888500,4818300,4790700,4749800,4713200,4650900]

# %%
fig, ax = plt.subplots()
plt.plot(years, total, c='r')
plt.plot(years, total_commsup, c='orange')
ax.set_ylim(bottom=0, top= 8000000)
plt.title('Incarceration Levels Steadily High Over 14 Year Period')
plt.legend(['Total Incarcerated Population', 'Community Supervision'], loc='lower right')
fig.savefig('Incarcerationplot.svg')
