# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
cnx = create_engine("postgresql://ubuntu:@18.216.189.42:5432/recidivism")
# Out:
# /anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
pd.read_sql_query("""
    SELECT * FROM iowa_201015 LIMIT 5;
""", cnx)
# Out:
#    year_released  reporting_year                  race   sex age_at_release  \
# 0           2014            2017  White - Non-Hispanic  None       Under 25
# 1           2014            2017  White - Non-Hispanic  None       Under 25
# 2           2014            2017  White - Non-Hispanic  None       Under 25
# 3           2014            2017  White - Non-Hispanic  None       Under 25
# 4           2014            2017  White - Non-Hispanic  None          25-34
#
#   conviction_class convicting_type conviction_subtype release_type  \
# 0         C Felony         Violent                Sex         None
# 1         C Felony         Violent                Sex         None
# 2         C Felony         Violent                Sex         None
# 3         C Felony         Violent                Sex         None
# 4         C Felony        Property           Burglary         None
#
#   supervising_district recidivism recidivism_type days_to_recidivism  \
# ...

# %%
df = pd.read_sql_query("""
    SELECT * FROM iowa_201015
""", cnx)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26020 entries, 0 to 26019
# Data columns (total 20 columns):
# year_released                    26020 non-null int64
# reporting_year                   26020 non-null int64
# race                             25990 non-null object
# sex                              0 non-null object
# age_at_release                   26017 non-null object
# conviction_class                 26020 non-null object
# convicting_type                  26020 non-null object
# conviction_subtype               26020 non-null object
# release_type                     24258 non-null object
# supervising_district             16439 non-null object
# recidivism                       26020 non-null object
# recidivism_type                  24258 non-null object
# days_to_recidivism               8681 non-null float64
# new_conviction_class             6718 non-null object
# new_conviction_type              6718 non-null object
# ...

# %%
df.to_csv('data/csv_fromAWSupload.csv')

# %%
df = pd.read_csv('data/csv_fromAWSupload.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  year_released  reporting_year                  race  sex  \
# 0           0           2014            2017  White - Non-Hispanic  NaN
# 1           1           2014            2017  White - Non-Hispanic  NaN
# 2           2           2014            2017  White - Non-Hispanic  NaN
# 3           3           2014            2017  White - Non-Hispanic  NaN
# 4           4           2014            2017  White - Non-Hispanic  NaN
#
#   age_at_release conviction_class convicting_type conviction_subtype  \
# 0       Under 25         C Felony         Violent                Sex
# 1       Under 25         C Felony         Violent                Sex
# 2       Under 25         C Felony         Violent                Sex
# 3       Under 25         C Felony         Violent                Sex
# 4          25-34         C Felony        Property           Burglary
#
#   release_type              ...               recidivism recidivism_type  \
# ...
